# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ICARUS.Vehicle.plane import Airplane
from ICARUS.Vehicle.wing_segment import Wing_Segment
from ICARUS.Vehicle.wing_segment import define_linear_chord
from ICARUS.Vehicle.wing_segment import define_linear_span
from ICARUS.Environment.definition import Environment
import avl.input as avlinp
import avl.polars as avlpol
import avl.dynamics as avldyn
import avl.post as avlpst

# %%
mw = Wing_Segment(
    name="Main_Wing_1",
    airfoil="2412",
    origin=np.array([0., 0., 0.]),
    orientation=np.array([0., 0., 0.]),
    is_symmetric=True,
    sweep_offset=0.1,
    span=2.0,
    dih_angle=0.0,
    chord_fun=define_linear_chord,
    chord=np.array([0.4, 0.4]),
    span_fun=define_linear_span,
    # twist_fun: Callable[[float, int], FloatArray],
    N=30,
    M=10,
    mass=1.0,
)
el = Wing_Segment(
    name="Elevator",
    airfoil="0012",
    origin=np.array([1.25, 0, 0]),
    orientation=np.array([0.0, 0.0, 0.0]),
    is_symmetric=True,
    sweep_offset=0.0,
    span=1.0,
    dih_angle=0.0,
    chord_fun=define_linear_chord,
    chord=np.array([0.2, 0.2]),
    span_fun=define_linear_span,
    # twist_fun: Callable[[float, int], FloatArray],
    N=20,
    M=5,
    mass=1.0,
)
rud = Wing_Segment(
    name="Rudder",
    airfoil="0012",
    origin=np.array([1.3, 0, 0.2]),
    orientation=np.array([0, 0., 90.0]),
    is_symmetric=True,
    sweep_offset=0.0,
    span=1.0,
    dih_angle=0.0,
    chord_fun=define_linear_chord,
    chord=np.array([0.1, 0.1]),
    span_fun=define_linear_span,
    # twist_fun: Callable[[float, int], FloatArray],
    N=20,
    M=5,
    mass=1.0,
)
w_polar = np.array([[-1, 0.23, 1.375], [0.034, 0.0064, 0.04]])  # NACA 2412 at Re = 5e5
el_polar = np.array(
    [[-1.15, 0, 1.15], [0.038, 0.00768, 0.038]]
)  # NACA 0012 at Re = 3e5
rud_polar = el_polar

pl = Airplane("plane_100", [mw, el, rud])

# %%
env = Environment("Default")

# %%
pms = [(1.9, [-0.1, 0, 0.2], "payload"), (1.9, [-0.1, 0, 0.2], "pa2")]
pl.add_point_masses(pms)

# %%
avlinp.avl_mass(pl,Env,1.)
avlinp.avl_geo(pl,1.0,1.0,w_polar,1.0,el_polar,1.0,rud_polar,"full")
avlinp.get_Inertias(pl)
# Out:
# OPA
# FULL MODEL
# ALL WINGS
# array([ 0.5713,  2.914 ,  3.17  , -0.915 , -0.    , -0.    ])

# %%
angles = np.linspace(-10,10,11)
avlpol.case_def(pl, angles)
avlpol.case_setup(pl)
avlpol.case_run(pl,angles)
pol_df = avlpst.polar_postprocess(pl,angles)
# Out:
#  ===================================================
#   Athena Vortex Lattice  Program      Version  3.40
#   Copyright (C) 2002   Mark Drela, Harold Youngren
#
#   This software comes with ABSOLUTELY NO WARRANTY,
#     subject to the GNU General Public License.
#
#   Caveat computor
#  ===================================================
#
#  ==========================================================
#    Quit    Exit program
#
#   .OPER    Compute operating-point run cases
#   .MODE    Eigenvalue analysis of run cases
#   .TIME    Time-domain calculations
#
#    LOAD f  Read configuration input file
#    MASS f  Read mass distribution file
#    CASE f  Read run case file
#
#    CINI    Clear and initialize run cases
#    MSET i  Apply mass file data to stored run case(s)
#
#   .PLOP    Plotting options
#    NAME s  Specify new configuration name
#
#  AVL   c>
#  Reading file: plane_100_genD/plane_100.avl  ...
#
#  Configuration: plane_100
#
#    Building surface: Main Wing
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.000  CD@CLneg =    0.03400
#      CL@CDmin =    0.230  CDmin    =    0.00640
#      CLpos    =    1.375  CD@CLpos =    0.04000
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA2412.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA2412.txt
#
#    Building duplicate image-surface: Main Wing (YDUP)
#
#    Building surface: Elevator
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.150  CD@CLneg =    0.03800
#      CL@CDmin =    0.000  CDmin    =    0.00768
#      CLpos    =    1.150  CD@CLpos =    0.03800
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#
#    Building duplicate image-surface: Elevator (YDUP)
#
#    Building surface: Fin
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.150  CD@CLneg =    0.03800
#      CL@CDmin =    0.000  CDmin    =    0.00768
#      CLpos    =    1.150  CD@CLpos =    0.03800
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#
#  Mach =    0.0000  (default)
#
#     0 Bodies
#     5 Solid surfaces
#   120 Strips
#   900 Vortices
#
#     0 Control variables
#     0 Design parameters
#
#  Initializing run cases...
#
#  AVL   c>
#  Mass distribution read ...
#
#  Mass        =    6.800      Munit
#  Mass        =    6.800      kg
#
#  Ref. x,y,z  =   0.3716       0.000      0.1808      Lunit
#  C.G. x,y,z  =   0.3716       0.000      0.1808      Lunit
#  C.G. x,y,z  =   0.3716       0.000      0.1808      m
#
#  Ixx -Ixy -Ixz   |   0.5713      -0.000     -0.9157E-01  |
#       Iyy -Iyz = |                2.914      -0.000      |  kg-m^2
#            Izz   |                            3.176      |
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#  Apparent mass, inertia
#
#  mxx  mxy  mxz   |    0.000       0.000       0.000      |
#       myy  myz = |               0.4810E-02 -0.2946E-18  |  kg
#            mzz   |                           0.3448      |
#
#  Ixx -Ixy -Ixz   |   0.1064     -0.7218E-17 -0.2922E-02  |
#       Iyy -Iyz = |               0.9031E-01  0.5369E-18  |  kg-m^2
#            Izz   |                           0.8768E-02  |
#
#  Use MSET to apply these mass,inertias to run cases
#
#  AVL   c>
#
#  Run cases read  ...
#     1: --10.0_deg-
#     2: --8.0_deg-
#     3: --6.0_deg-
#     4: --4.0_deg-
#     5: --2.0_deg-
#     6: -0.0_deg-
#     7: -2.0_deg-
#     8: -4.0_deg-
#     9: -6.0_deg-
#    10: -8.0_deg-
#    11: -10.0_deg-
#
#
#  AVL   c>
#  Enter index of target run case (0=all, -1=abort):  0
#
#  AVL   c>
#  Operation of run case 1/11:  --10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/11)   c>   Enter run case filename: plane_100_polarD/plane_100.run
#  File  plane_100_polarD/plane_100.run  exists.  Overwrite?  Y
#
#  Operation of run case 1/11:  --10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/11)   c>
#  AVL   c>
#  ===================================================
#   Athena Vortex Lattice  Program      Version  3.40
#   Copyright (C) 2002   Mark Drela, Harold Youngren
#
#   This software comes with ABSOLUTELY NO WARRANTY,
#     subject to the GNU General Public License.
#
#   Caveat computor
#  ===================================================
#
#  ==========================================================
#    Quit    Exit program
#
#   .OPER    Compute operating-point run cases
#   .MODE    Eigenvalue analysis of run cases
#   .TIME    Time-domain calculations
#
#    LOAD f  Read configuration input file
#    MASS f  Read mass distribution file
#    CASE f  Read run case file
#
#    CINI    Clear and initialize run cases
#    MSET i  Apply mass file data to stored run case(s)
#
#   .PLOP    Plotting options
#    NAME s  Specify new configuration name
#
#  AVL   c>
#  Reading file: plane_100_genD/plane_100.avl  ...
#
#  Configuration: plane_100
#
#    Building surface: Main Wing
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.000  CD@CLneg =    0.03400
#      CL@CDmin =    0.230  CDmin    =    0.00640
#      CLpos    =    1.375  CD@CLpos =    0.04000
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA2412.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA2412.txt
#
#    Building duplicate image-surface: Main Wing (YDUP)
#
#    Building surface: Elevator
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.150  CD@CLneg =    0.03800
#      CL@CDmin =    0.000  CDmin    =    0.00768
#      CLpos    =    1.150  CD@CLpos =    0.03800
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#
#    Building duplicate image-surface: Elevator (YDUP)
#
#    Building surface: Fin
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.150  CD@CLneg =    0.03800
#      CL@CDmin =    0.000  CDmin    =    0.00768
#      CLpos    =    1.150  CD@CLpos =    0.03800
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#
#  Mach =    0.0000  (default)
#
#     0 Bodies
#     5 Solid surfaces
#   120 Strips
#   900 Vortices
#
#     0 Control variables
#     0 Design parameters
#
#  Initializing run cases...
#
#  AVL   c>
#  Mass distribution read ...
#
#  Mass        =    6.800      Munit
#  Mass        =    6.800      kg
#
#  Ref. x,y,z  =   0.3716       0.000      0.1808      Lunit
#  C.G. x,y,z  =   0.3716       0.000      0.1808      Lunit
#  C.G. x,y,z  =   0.3716       0.000      0.1808      m
#
#  Ixx -Ixy -Ixz   |   0.5713      -0.000     -0.9157E-01  |
#       Iyy -Iyz = |                2.914      -0.000      |  kg-m^2
#            Izz   |                            3.176      |
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#  Apparent mass, inertia
#
#  mxx  mxy  mxz   |    0.000       0.000       0.000      |
#       myy  myz = |               0.4810E-02 -0.2946E-18  |  kg
#            mzz   |                           0.3448      |
#
#  Ixx -Ixy -Ixz   |   0.1064     -0.7218E-17 -0.2922E-02  |
#       Iyy -Iyz = |               0.9031E-01  0.5369E-18  |  kg-m^2
#            Izz   |                           0.8768E-02  |
#
#  Use MSET to apply these mass,inertias to run cases
#
#  AVL   c>
#
#  Run cases read  ...
#     1: --10.0_deg-
#     2: --8.0_deg-
#     3: --6.0_deg-
#     4: --4.0_deg-
#     5: --2.0_deg-
#     6: -0.0_deg-
#     7: -2.0_deg-
#     8: -4.0_deg-
#     9: -6.0_deg-
#    10: -8.0_deg-
#    11: -10.0_deg-
#
#
#  AVL   c>
#  AVL   c>
#  Operation of run case 1/11:  --10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/11)   c>
#  Operation of run case 1/11:  --10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/11)   c>    Building normalwash AIC matrix...
#   Factoring normalwash AIC matrix...
#   Building source+doublet strength AIC matrix...
#   Building source+doublet velocity AIC matrix...
#   Building bound-vortex velocity matrix...
#
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: --10.0_deg-
#
#   Alpha = -10.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =   0.06414     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =  -0.07212
#   CZtot =   0.64852     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =  -0.64981
#   CDtot =   0.04945
#   CDvis =   0.02109     CDind = 0.0283570
#   CLff  =  -0.65481     CDff  = 0.0123475    | Trefftz
#   CYff  =  -0.00000         e =    2.2107    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 1/11:  --10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 1/11:  --10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/11)   c>
#  Operation of run case 2/11:  --8.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -8.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 2/11)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: --8.0_deg-
#
#   Alpha =  -8.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =   0.03545     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =  -0.05061
#   CZtot =   0.49508     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =  -0.49519
#   CDtot =   0.03380
#   CDvis =   0.01711     CDind = 0.0166880
#   CLff  =  -0.49754     CDff  = 0.0065966    | Trefftz
#   CYff  =  -0.00000         e =    2.3890    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 2/11:  --8.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -8.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 2/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 2/11:  --8.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -8.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 2/11)   c>
#  Operation of run case 3/11:  --6.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -6.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 3/11)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: --6.0_deg-
#
#   Alpha =  -6.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =   0.01359     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =  -0.02561
#   CZtot =   0.33925     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =  -0.33881
#   CDtot =   0.02194
#   CDvis =   0.01388     CDind = 0.0080611
#   CLff  =  -0.33966     CDff  = 0.0026648    | Trefftz
#   CYff  =  -0.00000         e =    2.7560    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 3/11:  --6.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -6.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 3/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 3/11:  --6.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -6.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 3/11)   c>
#  Operation of run case 4/11:  --4.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -4.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 4/11)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: --4.0_deg-
#
#   Alpha =  -4.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =  -0.00135     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =   0.00276
#   CZtot =   0.18172     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =  -0.18118
#   CDtot =   0.01402
#   CDvis =   0.01143     CDind = 0.0025912
#   CLff  =  -0.18136     CDff  = 0.0005714    | Trefftz
#   CYff  =  -0.00000         e =    3.6648    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 4/11:  --4.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -4.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 4/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 4/11:  --4.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -4.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 4/11)   c>
#  Operation of run case 5/11:  --2.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -2.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 5/11)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: --2.0_deg-
#
#   Alpha =  -2.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =  -0.00934     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =   0.03438
#   CZtot =   0.02318     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =  -0.02284
#   CDtot =   0.01014
#   CDvis =   0.00978     CDind = 0.0003548
#   CLff  =  -0.02285     CDff  = 0.0003264    | Trefftz
#   CYff  =  -0.00000         e =    0.1018    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 5/11:  --2.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -2.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 5/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 5/11:  --2.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =  -2.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 5/11)   c>
#  Operation of run case 6/11:  -0.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   0.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 6/11)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: -0.0_deg-
#
#   Alpha =   0.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =  -0.01034     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =   0.06911
#   CZtot =  -0.13569     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =   0.13569
#   CDtot =   0.01034
#   CDvis =   0.00895     CDind = 0.0013888
#   CLff  =   0.13569     CDff  = 0.0019311    | Trefftz
#   CYff  =  -0.00000         e =    0.6070    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 6/11:  -0.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   0.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 6/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 6/11:  -0.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   0.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
# ...
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: -6.0_deg-
#
#   Alpha =   6.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =   0.02751     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =   0.19017
#   CZtot =  -0.60750     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =   0.60705
#   CDtot =   0.03614
#   CDvis =   0.01225     CDind = 0.0238868
#   CLff  =   0.60956     CDff  = 0.0177205    | Trefftz
#   CYff  =  -0.00000         e =    1.3349    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 9/11:  -6.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   6.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 9/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 9/11:  -6.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   6.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 9/11)   c>
#  Operation of run case 10/11:  -8.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   8.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 10/11)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: -8.0_deg-
#
#   Alpha =   8.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =   0.05339     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =   0.23555
#   CZtot =  -0.76098     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =   0.76100
#   CDtot =   0.05303
#   CDvis =   0.01545     CDind = 0.0375791
#   CLff  =   0.76628     CDff  = 0.0265565    | Trefftz
#   CYff  =  -0.00000         e =    1.4076    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 10/11:  -8.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   8.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 10/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 10/11:  -8.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   8.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 10/11)   c>
#  Operation of run case 11/11:  -10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 11/11)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.37159       Yref =  0.0000       Zref = 0.18076
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case: -10.0_deg-
#
#   Alpha =  10.00000     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =   0.08580     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =   0.28318
#   CZtot =  -0.91148     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =   0.91253
#   CDtot =   0.07378
#   CDvis =   0.01964     CDind = 0.0541365
#   CLff  =   0.92207     CDff  = 0.0371144    | Trefftz
#   CYff  =  -0.00000         e =    1.4584    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 11/11:  -10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 11/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 11/11:  -10.0_deg-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   10.00
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 11/11)   c>
#  AVL   c>

# %%
plt.plot(pol_df[0], pol_df[1])
plt.axhline()
plt.grid(True)
plt.axvline()
plt.show()
plt.plot(pol_df[0], pol_df[2])
plt.axhline()
plt.axvline()
plt.grid(True)
plt.show()
plt.plot(pol_df[0], pol_df[3])
plt.axhline()
plt.axvline()
plt.grid(True)
plt.show()

# %%
trims = avldyn.trim_conditions(pl)
# Out:
# 12432
# 793
# 6682

# %%
impl_eigs = avldyn.implicit_eigs(pl)
impl_long = np.array(impl_eigs[0]).reshape((4, 2))
# Out:
# mkdir: cannot create directory ‘plane_100_eigD’: File exists
# /home/titos/Hermes/Refactored_AVL
# 3826
# 1570
# 2151
# 3215
# 1670
# 793
# 664
# 2813
# 3981
# 59
# 4210
# 4852
# /home/titos/Hermes/Refactored_AVL
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 impl_eigs = avldyn.implicit_eigs(pl)
#       2 impl_long = np.array(impl_eigs[0]).reshape((4, 2))
#
# File ~/Hermes/Refactored_AVL/avl/dynamics.py:57, in implicit_eigs(plane)
#      55 ind_li = np.arange(0, 8, 1) * 6
#      56 for i in ind_li:
# ---> 57     vals = eigpro(i, lines)
#      58     if np.mean(np.abs(vals[0])) == 0:
#      59         lat_li.append(vals[2])
#
# File ~/Hermes/Refactored_AVL/avl/dynamics.py:72, in eigpro(st, lines)
#      70 def eigpro(st, lines):
#      71     st = int(st)
# ---> 72     mode = np.array([float(lines[st][10:22]), float(lines[st][24:32])])
#      73     long_vecs = np.zeros((4, 2))
#      74     lat_vecs = np.zeros((4, 2))
#
# ValueError: could not convert string to float: ' 0.754610-31'

# %%
trims[1]
# Out:
# 49.91

# %%
u_inc = np.logspace(-3, -2, 1) * trims[1]
th_inc = np.logspace(-3, -2, 1)*trims[1]/2
u_ar = u_inc
w_ar = u_inc
v_ar = u_inc
q_ar = th_inc
p_ar = th_inc
r_ar = th_inc
avldyn.finite_difs(
    plane=pl,
    u_ar=u_ar,
    w_ar=w_ar,
    q_ar=q_ar,
    p_ar=p_ar,
    r_ar=r_ar,
    v_ar=v_ar,
    trim_conditions=trims,
)
# Out:
# 0.049909999999999996
#
#  ===================================================
#   Athena Vortex Lattice  Program      Version  3.40
#   Copyright (C) 2002   Mark Drela, Harold Youngren
#
#   This software comes with ABSOLUTELY NO WARRANTY,
#     subject to the GNU General Public License.
#
#   Caveat computor
#  ===================================================
#
#  ==========================================================
#    Quit    Exit program
#
#   .OPER    Compute operating-point run cases
#   .MODE    Eigenvalue analysis of run cases
#   .TIME    Time-domain calculations
#
#    LOAD f  Read configuration input file
#    MASS f  Read mass distribution file
#    CASE f  Read run case file
#
#    CINI    Clear and initialize run cases
#    MSET i  Apply mass file data to stored run case(s)
#
#   .PLOP    Plotting options
#    NAME s  Specify new configuration name
#
#  AVL   c>
#  Reading file: plane_100_genD/plane_100.avl  ...
#
#  Configuration: plane_100
#
#    Building surface: Main Wing
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.000  CD@CLneg =    0.03400
#      CL@CDmin =    0.230  CDmin    =    0.00640
#      CLpos    =    1.375  CD@CLpos =    0.04000
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA2412.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA2412.txt
#
#    Building duplicate image-surface: Main Wing (YDUP)
#
#    Building surface: Elevator
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.150  CD@CLneg =    0.03800
#      CL@CDmin =    0.000  CDmin    =    0.00768
#      CLpos    =    1.150  CD@CLpos =    0.03800
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#
#    Building duplicate image-surface: Elevator (YDUP)
#
#    Building surface: Fin
#  ** Polar data for surface (all sections)
#     Reading CD(CL) data for surface
#      CLneg    =   -1.150  CD@CLneg =    0.03800
#      CL@CDmin =    0.000  CDmin    =    0.00768
#      CLpos    =    1.150  CD@CLpos =    0.03800
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#      Reading airfoil from file: /home/titos/Hermes/Refactored_AVL/avl/../NACA0012.txt
#
#  Mach =    0.0000  (default)
#
#     0 Bodies
#     5 Solid surfaces
#   120 Strips
#   900 Vortices
#
#     0 Control variables
#     0 Design parameters
#
#  Initializing run cases...
#
#  AVL   c>
#  Mass distribution read ...
#
#  Mass        =    13.40      Munit
#  Mass        =    13.40      kg
#
#  Ref. x,y,z  =   0.1393       0.000      0.1902      Lunit
#  C.G. x,y,z  =   0.1393       0.000      0.1902      Lunit
#  C.G. x,y,z  =   0.1393       0.000      0.1902      m
#
#  Ixx -Ixy -Ixz   |   0.5725      -0.000     -0.6119E-01  |
#       Iyy -Iyz = |                3.660      -0.000      |  kg-m^2
#            Izz   |                            3.921      |
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#  Apparent mass, inertia
#
#  mxx  mxy  mxz   |    0.000       0.000       0.000      |
#       myy  myz = |               0.4810E-02 -0.2946E-18  |  kg
#            mzz   |                           0.3448      |
#
#  Ixx -Ixy -Ixz   |   0.1064     -0.7218E-17 -0.2922E-02  |
#       Iyy -Iyz = |               0.9031E-01  0.5369E-18  |  kg-m^2
#            Izz   |                           0.8768E-02  |
#
#  Use MSET to apply these mass,inertias to run cases
#
#  AVL   c>
#  Enter index of target run case (0=all, -1=abort):  0
#
#  AVL   c>
#  Operation of run case 1/1:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   0.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/1)   c>
#  Operation of run case 1/1:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       =   0.000
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/1)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#    ->  A    alpha       =   0.000
#        B    beta        =   0.000
#        R    pb/2V       =   0.000
#        P    qc/2V       =   0.000
#        Y    rb/2V       =   0.000
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for alpha          c>
#  Enter specified alpha       :   0.000
#
#  Operation of run case 1/1:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.2960
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/1)   c>    Building normalwash AIC matrix...
#   Factoring normalwash AIC matrix...
#   Building source+doublet strength AIC matrix...
#   Building source+doublet velocity AIC matrix...
#   Building bound-vortex velocity matrix...
#
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.13931       Yref =  0.0000       Zref = 0.19024
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case:  -unnamed-
#
#   Alpha =  -0.29602     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =  -0.01063     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =  -0.00162
#   CZtot =  -0.11219     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =   0.11224
#   CDtot =   0.01005
#   CDvis =   0.00902     CDind = 0.0010292
#   CLff  =   0.11223     CDff  = 0.0015772    | Trefftz
#   CYff  =  -0.00000         e =    0.5084    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 1/1:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.2960
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/1)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 1/1:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.2960
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 1/1)   c>   Initializing new run case from current one
#
#  Operation of run case 2/2:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.2960
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 2/2)   c>
#  Operation of run case 2/2:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.2960
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 2/2)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#    ->  A    alpha       = -0.2960
#        B    beta        =   0.000
#        R    pb/2V       =   0.000
#        P    qc/2V       =   0.000
#        Y    rb/2V       =   0.000
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for alpha          c>
#  Enter specified alpha       : -0.2960
#
#  Operation of run case 2/2:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.4106
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 2/2)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.13931       Yref =  0.0000       Zref = 0.19024
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case:  -unnamed-
#
#   Alpha =  -0.41062     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =  -0.01071     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =   0.00162
#   CZtot =  -0.10308     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =   0.10316
#   CDtot =   0.00997
#   CDvis =   0.00906     CDind = 0.0009093
#   CLff  =   0.10315     CDff  = 0.0014510    | Trefftz
#   CYff  =  -0.00000         e =    0.4668    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 2/2:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.4106
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 2/2)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 2/2:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.4106
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 2/2)   c>   Initializing new run case from current one
#
#  Operation of run case 3/3:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.4106
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 3/3)   c>
#  Operation of run case 3/3:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.4106
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 3/3)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#    ->  A    alpha       = -0.4106
#        B    beta        =   0.000
#        R    pb/2V       =   0.000
#        P    qc/2V       =   0.000
#        Y    rb/2V       =   0.000
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for alpha          c>
#  Enter specified alpha       : -0.4106
#
#  Operation of run case 3/3:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3530
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 3/3)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.13931       Yref =  0.0000       Zref = 0.19024
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case:  -unnamed-
#
#   Alpha =  -0.35297     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =  -0.01067     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =  -0.00001
#   CZtot =  -0.10766     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =   0.10773
#   CDtot =   0.01001
#   CDvis =   0.00904     CDind = 0.0009683
#   CLff  =   0.10772     CDff  = 0.0015137    | Trefftz
#   CYff  =  -0.00000         e =    0.4880    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 3/3:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3530
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 3/3)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 3/3:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3530
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 3/3)   c>   Initializing new run case from current one
#
#  Operation of run case 4/4:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3530
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 4/4)   c>
#  Operation of run case 4/4:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3530
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 4/4)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#    ->  A    alpha       = -0.3530
#        B    beta        =   0.000
#        R    pb/2V       =   0.000
#        P    qc/2V       =   0.000
#        Y    rb/2V       =   0.000
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for alpha          c>
#  Enter specified alpha       : -0.3530
#
#  Operation of run case 4/4:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3537
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 4/4)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.000E+00 -0.000E+00  0.000E+00
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.13931       Yref =  0.0000       Zref = 0.19024
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case:  -unnamed-
#
#   Alpha =  -0.35367     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00000     r'b/2V =  -0.00000
#
#   CXtot =  -0.01067     Cltot =  -0.00000     Cl'tot =  -0.00000
#   CYtot =  -0.00000     Cmtot =   0.00001
#   CZtot =  -0.10761     Cntot =   0.00000     Cn'tot =   0.00000
#
#   CLtot =   0.10767
#   CDtot =   0.01001
#   CDvis =   0.00904     CDind = 0.0009676
#   CLff  =   0.10766     CDff  = 0.0015130    | Trefftz
#   CYff  =  -0.00000         e =    0.4877    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 4/4:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3537
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 4/4)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 4/4:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3537
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 4/4)   c>   Initializing new run case from current one
#
#  Operation of run case 5/5:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3537
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 5/5)   c>
#  Operation of run case 5/5:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3537
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 5/5)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#    ->  A    alpha       = -0.3537
#        B    beta        =   0.000
#        R    pb/2V       =   0.000
#        P    qc/2V       =   0.000
#        Y    rb/2V       =   0.000
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for alpha          c>
#  Enter specified alpha       : -0.3537
#
#  Operation of run case 5/5:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =   0.000
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 5/5)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#        A    alpha       = -0.3533
#        B    beta        =   0.000
#        R    pb/2V       =   0.000
#    ->  P    qc/2V       =   0.000
#        Y    rb/2V       =   0.000
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for qc/2V          c>
#  Enter specified qc/2V       :   0.000
#
#  Operation of run case 5/5:   -unnamed-
# ...
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 11/11)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 11/11:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =  0.5000E-03
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 11/11)   c>   Initializing new run case from current one
#
#  Operation of run case 12/12:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =  0.5000E-03
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 12/12)   c>
#  Operation of run case 12/12:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =  0.5000E-03
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 12/12)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#    ->  A    alpha       = -0.3533
#        B    beta        =   0.000
#        R    pb/2V       =   0.000
#        P    qc/2V       =   0.000
#        Y    rb/2V       =  0.5000E-03
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for alpha          c>
#  Enter specified alpha       : -0.3533
#
#  Operation of run case 12/12:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =  0.5000E-03
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 12/12)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#        A    alpha       = -0.3533
#    ->  B    beta        =   0.000
#        R    pb/2V       =   0.000
#        P    qc/2V       =   0.000
#        Y    rb/2V       =  0.5000E-03
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for beta           c>
#  Enter specified beta        :   0.000
#
#  Operation of run case 12/12:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       =  0.5000E-03
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 12/12)   c>
#        constraint            value
#       - - - - - - - - - - - - - - - - -
#        A    alpha       = -0.3533
#        B    beta        =   0.000
#        R    pb/2V       =   0.000
#        P    qc/2V       =   0.000
#    ->  Y    rb/2V       =  0.5000E-03
#        C    CL          =   0.000
#        S    CY          =   0.000
#        RM   Cl roll mom =   0.000
#        PM   Cm pitchmom =   0.000
#        YM   Cn yaw  mom =   0.000
#
#       Select new  constraint,value  for rb/2V          c>
#  Enter specified rb/2V       :  0.5000E-03
#
#  Operation of run case 12/12:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       = -0.5000E-03
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 12/12)   c>
#  iter d(alpha)   d(beta)    d(pb/2V)   d(qc/2V)   d(rb/2V)
#    1 -0.000E+00 -0.000E+00  0.308E-05 -0.000E+00  0.100E-02
#    2 -0.000E+00 -0.000E+00  0.158E-20 -0.000E+00  0.325E-18
#  ---------------------------------------------------------------
#  Vortex Lattice Output -- Total Forces
#
#  Configuration: plane_100
#      # Surfaces =   5
#      # Strips   = 120
#      # Vortices = 900
#
#   Sref = 0.80000       Cref = 0.40000       Bref =  2.0000
#   Xref = 0.13931       Yref =  0.0000       Zref = 0.19024
#
#  Standard axis orientation,  X fwd, Z down
#
#  Run case:  -unnamed-
#
#   Alpha =  -0.35332     pb/2V =  -0.00000     p'b/2V =  -0.00000
#   Beta  =   0.00000     qc/2V =   0.00000
#   Mach  =     0.000     rb/2V =  -0.00050     r'b/2V =  -0.00050
#
#   CXtot =  -0.01067     Cltot =  -0.00003     Cl'tot =  -0.00003
#   CYtot =  -0.00015     Cmtot =  -0.00000
#   CZtot =  -0.10763     Cntot =   0.00009     Cn'tot =   0.00009
#
#   CLtot =   0.10770
#   CDtot =   0.01001
#   CDvis =   0.00904     CDind = 0.0009679
#   CLff  =   0.10769     CDff  = 0.0015134    | Trefftz
#   CYff  =  -0.00015         e =    0.4879    | Plane
#
#
#  ---------------------------------------------------------------
#
#  Operation of run case 12/12:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       = -0.5000E-03
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 12/12)   c>
# Enter filename, or <return> for screen output   s>
#  Operation of run case 12/12:   -unnamed-
#  ==========================================================
#
#   variable          constraint
#   ------------      ------------------------
#   A lpha        ->  alpha       = -0.3533
#   B eta         ->  beta        =   0.000
#   R oll  rate   ->  pb/2V       =   0.000
#   P itch rate   ->  qc/2V       =   0.000
#   Y aw   rate   ->  rb/2V       = -0.5000E-03
#   ------------      ------------------------
#
#   C1  set level or banked  horizontal flight constraints
#   C2  set steady pitch rate (looping) flight constraints
#   M odify parameters
#
#  "#" select  run case          L ist defined run cases
#   +  add new run case          S ave run cases to file
#   -  delete  run case          F etch run cases from file
#   N ame current run case       W rite forces to file
#
#  eX ecute run case             I nitialize variables
#
#   G eometry plot               T refftz Plane plot
#
#   ST  stability derivatives    FT  total   forces
#   SB  body-axis derivatives    FN  surface forces
#   RE  reference quantities     FS  strip   forces
#   DE  design changes           FE  element forces
#   O ptions                     FB  body forces
#                                HM  hinge moments
#                                VM  strip shear,moment
#   MRF  machine-readable format CPOM OML surface pressures
#
#  .OPER (case 12/12)   c>
#  AVL   c>

# %%
Is = avlinp.get_Inertias(pl)

# %%
w_dict = avlpst.finite_difs_post(pl, w_ar, "w")
q_dict = avlpst.finite_difs_post(pl, q_ar, "q")
u_dict = avlpst.finite_difs_post(pl, u_ar, "u")

# %%
long_mat =avldyn.long_mat(pl,env,trims[0],trims[1],u_dict,Is,w_dict,q_dict,pl.span)
# Out:
# 9.96384294985728

# %%
fd_eigs,eigv = np.linalg.eig(long_mat)

# %%
plt.scatter(fd_eigs.real,fd_eigs.imag,label = "FD")
plt.scatter(impl_long[:,0],impl_long[:,1],label = "ID")
plt.grid(True)
plt.legend()
